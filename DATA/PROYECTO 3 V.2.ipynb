# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# %%
from joblib import Parallel, delayed

# %%
from selenium.webdriver.common.by import By

# %%
import re

# %%
import pandas as pd

# %%
import time

# %%
from sqlalchemy import create_engine

# %%
pd.set_option('display.max_columns', None) 
pd.set_option('display.max_rows', None)

# %%
forbes = 'https://forbes.es/mas-ricos-espana/2021-a/lista-100-mas-ricos-espana-2021/'

# %%
#driver configuration
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False     # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
#opciones.add_extension('driver_folder/adblock.crx')       # adblocker
opciones.add_argument('--incognito')

# %%
from joblib import Parallel, delayed

# %%
PATH=ChromeDriverManager().install()

driver=webdriver.Chrome(PATH)
# Out:
# /var/folders/fg/hm_rz3k53fv5qf5dywc0bfwr0000gn/T/ipykernel_5115/1553837471.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(PATH)

# %%
driver.get(forbes)

# %%
nombres = driver.find_elements(By.TAG_NAME, 'h2')

# %%
nombres_forbes = [e.text.split('\n')[-1] for e in nombres]

# %%
nombres_forbes
# Out:
# ['Amancio Ortega',
#  'Sandra Ortega Mera',
#  'Rafael del Pino y Calvo-Sotelo',
#  'Juan Roig Alfonso',
#  'Juan Carlos Escotet',
#  'Juan Abelló',
#  'Newsletter',
#  '',
#  '']

# %%
len(nombres_forbes)
# Out:
# 9

# %%
nombres_forbes = nombres_forbes[0:6]

# %%
nombres_forbes
# Out:
# ['Amancio Ortega',
#  'Sandra Ortega Mera',
#  'Rafael del Pino y Calvo-Sotelo',
#  'Juan Roig Alfonso',
#  'Juan Carlos Escotet',
#  'Juan Abelló']

# %%
nombres2 = driver.find_elements(By.CLASS_NAME, 'mas-ricos--nombre')

# %%
nombres_forbes2 = [e.text.split('(c/u)')[0] for e in nombres2]

# %%
nombres_forbes2
# Out:
# ['Alicia Koplowitz',
#  'Hortensia Herrero',
#  'María Del Pino y Calvo-Sotelo',
#  'Daniel Maté',
#  'Sol Daurella Comadrán',
#  'Florentino Pérez',
#  'Leopoldo Del Pino y Calvo-Sotelo',
#  'Isak Andic',
#  'Fernando Roig Alfonso',
#  'Tomás Olivo',
#  'Juan María Riberas Mera',
#  'Francisco Riberas Mera',
#  'Manuel Lao',
#  'Alberto Palatchi',
#  'Helena Revoredo',
#  'Miguel Fluxà Rosselló',
#  'Alberto Cortina',
#  'Alberto Alcocer',
#  'Antonio Gallardo Ballart',
#  'Jorge Gallardo Ballart',
#  'José María Aristrain',
#  'Carmen Daurella Aguilera',
#  'Juan Miguel Villar-Mir y familia',
#  'Gabriel Escarrer',
#  'José Elías',
#  'Manuel Puig Rocha',
#  'Joaquín Del Pino y Calvo-Sotelo',
#  'Thomas Andreas Meyer',
#  'Carlos March Delgado',
#  'Ricardo Portabella',
#  'Juan March Delgado',
#  'Julio Iglesias',
#  'Carmen Thyssen-Bornemisza',
#  'José Lladó',
#  'Álvaro Entrecanales Domecq',
#  'Juan Luis Arregui',
#  'Víctor de Urrutia Vallejo',
#  'Óscar Serra Duffo',
# ...

# %%
nombres_spain = nombres_forbes + nombres_forbes2

# %%
len(nombres_spain)
# Out:
# 100

# %%
nombres_spain2 =  []
for e in nombres_spain:
    nombres_spain2.append(list({e}))

# %%
nombres_spain2
# Out:
# [['Amancio Ortega'],
#  ['Sandra Ortega Mera'],
#  ['Rafael del Pino y Calvo-Sotelo'],
#  ['Juan Roig Alfonso'],
#  ['Juan Carlos Escotet'],
#  ['Juan Abelló'],
#  ['Alicia Koplowitz'],
#  ['Hortensia Herrero'],
#  ['María Del Pino y Calvo-Sotelo'],
#  ['Daniel Maté'],
#  ['Sol Daurella Comadrán'],
#  ['Florentino Pérez'],
#  ['Leopoldo Del Pino y Calvo-Sotelo'],
#  ['Isak Andic'],
#  ['Fernando Roig Alfonso'],
#  ['Tomás Olivo'],
#  ['Juan María Riberas Mera'],
#  ['Francisco Riberas Mera'],
#  ['Manuel Lao'],
#  ['Alberto Palatchi'],
#  ['Helena Revoredo'],
#  ['Miguel Fluxà Rosselló'],
#  ['Alberto Cortina'],
#  ['Alberto Alcocer'],
#  ['Antonio Gallardo Ballart'],
#  ['Jorge Gallardo Ballart'],
#  ['José María Aristrain'],
#  ['Carmen Daurella Aguilera'],
#  ['Juan Miguel Villar-Mir y familia'],
#  ['Gabriel Escarrer'],
#  ['José Elías'],
#  ['Manuel Puig Rocha'],
#  ['Joaquín Del Pino y Calvo-Sotelo'],
#  ['Thomas Andreas Meyer'],
#  ['Carlos March Delgado'],
# ...

# %%
driver.find_element(By.CLASS_NAME, 'mas-ricos-detalle__datos').text
# Out:
# 'ACCIONISTA MAYORITARIO DE INDITEX\nCONFECCIÓNGALICIA€67.000 M'

# %%
datos_forbes = driver.find_elements(By.CLASS_NAME, 'mas-ricos-detalle__datos')

# %%
datos_forbes1 = [e.text.split('€') for e in datos_forbes]

# %%
datos_forbes1
# Out:
# [['ACCIONISTA MAYORITARIO DE INDITEX\nCONFECCIÓNGALICIA', '67.000 M'],
#  ['ACCIONISTA DE INDITEX\nCONFECCIÓNGALICIA', '6.300 M'],
#  ['PRESIDENTE DE FERROVIAL\nINFRAESTRUCTURASMADRID', '3.800 M'],
#  ['PRESIDENTE DE MERCADONA\nDISTRIBUCIÓNC. VALENCIANA', '3.700 M'],
#  ['PRESIDENTE DEL BANESCO GRUPO FINANCIERO INTERNACIONAL Y DE ABANCA CORPORACIÓN BANCARIA\nINVERSIONESGALICIA',
#   '2.700 M'],
#  ['PRESIDENTE DE HONOR DE TORREAL\nINVERSIONESMADRID', '2.500 M']]

# %%
datos_forbess = driver.find_elements(By.CLASS_NAME, 'mas-ricos-listado-cien')

# %%
datos_forbes2 = [e.text.split('\n')[-3::] for e in datos_forbess]

# %%
datos_forbes2
# Out:
# [['PROPIETARIA DE OMEGA CAPITAL', '2.300 M€', 'MADRID'],
#  ['ACCIONISTA DE MERCADONA', '2.300 M€', 'C.VALENCIANA'],
#  ['PRESIDENTA DE LA FUNDACIÓN RAFAEL DEL PINO', '2.200 M€', 'MADRID'],
#  ['ACCIONISTA DE GLENCORE', '2.200 M€', 'PAÍS VASCO'],
#  ['PRESIDENTA DE COCA-COLA EUROPACIFIC PARTNERS', '1.900 M€', 'CATALUÑA'],
#  ['PRESIDENTE DE ACS', '1.700 M€', 'MADRID'],
#  ['ACCIONISTA DE FERROVIAL', '1.600 M€', 'MADRID'],
#  ['PROPIETARIO DE MANGO', '1.600 M€', 'CATALUÑA'],
#  ['PROPIETARIO DE PAMESA', '1.400 M€', 'C.VALENCIANA'],
#  ['PROPIETARIO DE GENERAL DE GALERÍAS COMERCIALES', '1.300 M€', 'MURCIA'],
#  ['ACCIONISTA DE GRUPO GESTAMP', '1.300 M€', 'MADRID'],
#  ['ACCIONISTA DE GRUPO GESTAMP', '1.300 M€', 'MADRID'],
#  ['EXPROPIETARIO DE CIRSA', '1.300 M€', 'CATALUÑA'],
#  ['EXPROPIETARIO DE PRONOVIAS', '1.300 M€', 'CATALUÑA'],
#  ['PRESIDENTA DE PROSEGUR', '1.300 M€', 'MADRID'],
#  ['PRESIDENTE EJECUTIVO DEL GRUPO IBEROSTAR', '1.200 M€', 'BALEARES'],
# ...

# %%
datos_forbes = datos_forbes1 + datos_forbes2

# %%
datos_forbes
# Out:
# [['ACCIONISTA MAYORITARIO DE INDITEX\nCONFECCIÓNGALICIA', '67.000 M'],
#  ['ACCIONISTA DE INDITEX\nCONFECCIÓNGALICIA', '6.300 M'],
#  ['PRESIDENTE DE FERROVIAL\nINFRAESTRUCTURASMADRID', '3.800 M'],
#  ['PRESIDENTE DE MERCADONA\nDISTRIBUCIÓNC. VALENCIANA', '3.700 M'],
#  ['PRESIDENTE DEL BANESCO GRUPO FINANCIERO INTERNACIONAL Y DE ABANCA CORPORACIÓN BANCARIA\nINVERSIONESGALICIA',
#   '2.700 M'],
#  ['PRESIDENTE DE HONOR DE TORREAL\nINVERSIONESMADRID', '2.500 M'],
#  ['PROPIETARIA DE OMEGA CAPITAL', '2.300 M€', 'MADRID'],
#  ['ACCIONISTA DE MERCADONA', '2.300 M€', 'C.VALENCIANA'],
#  ['PRESIDENTA DE LA FUNDACIÓN RAFAEL DEL PINO', '2.200 M€', 'MADRID'],
#  ['ACCIONISTA DE GLENCORE', '2.200 M€', 'PAÍS VASCO'],
#  ['PRESIDENTA DE COCA-COLA EUROPACIFIC PARTNERS', '1.900 M€', 'CATALUÑA'],
#  ['PRESIDENTE DE ACS', '1.700 M€', 'MADRID'],
#  ['ACCIONISTA DE FERROVIAL', '1.600 M€', 'MADRID'],
#  ['PROPIETARIO DE MANGO', '1.600 M€', 'CATALUÑA'],
# ...

# %%
columnas = ['NOMBRE']

# %%
df_forbes_sp = pd.DataFrame(nombres_spain, columns = columnas)

# %%
df_forbes_sp
# Out:
#                                                NOMBRE
# 0                                      Amancio Ortega
# 1                                  Sandra Ortega Mera
# 2                      Rafael del Pino y Calvo-Sotelo
# 3                                   Juan Roig Alfonso
# 4                                 Juan Carlos Escotet
# 5                                         Juan Abelló
# 6                                    Alicia Koplowitz
# 7                                   Hortensia Herrero
# 8                       María Del Pino y Calvo-Sotelo
# 9                                         Daniel Maté
# 10                              Sol Daurella Comadrán
# 11                                   Florentino Pérez
# 12                   Leopoldo Del Pino y Calvo-Sotelo
# 13                                         Isak Andic
# 14                              Fernando Roig Alfonso
# 15                                        Tomás Olivo
# ...

# %%
columnas1 = ['EMPRESA', 'CIFRA', 'CIUDAD']

# %%
df_3 = pd.DataFrame(datos_forbes, columns = columnas1)

# %%
df_3
# Out:
#                                               EMPRESA     CIFRA  \
# 0   ACCIONISTA MAYORITARIO DE INDITEX\nCONFECCIÓNG...  67.000 M
# 1            ACCIONISTA DE INDITEX\nCONFECCIÓNGALICIA   6.300 M
# 2     PRESIDENTE DE FERROVIAL\nINFRAESTRUCTURASMADRID   3.800 M
# 3   PRESIDENTE DE MERCADONA\nDISTRIBUCIÓNC. VALENC...   3.700 M
# 4   PRESIDENTE DEL BANESCO GRUPO FINANCIERO INTERN...   2.700 M
# 5   PRESIDENTE DE HONOR DE TORREAL\nINVERSIONESMADRID   2.500 M
# 6                        PROPIETARIA DE OMEGA CAPITAL  2.300 M€
# 7                             ACCIONISTA DE MERCADONA  2.300 M€
# 8          PRESIDENTA DE LA FUNDACIÓN RAFAEL DEL PINO  2.200 M€
# 9                              ACCIONISTA DE GLENCORE  2.200 M€
# 10       PRESIDENTA DE COCA-COLA EUROPACIFIC PARTNERS  1.900 M€
# 11                                  PRESIDENTE DE ACS  1.700 M€
# 12                            ACCIONISTA DE FERROVIAL  1.600 M€
# 13                               PROPIETARIO DE MANGO  1.600 M€
# ...

# %%
df_3.head(7)
# Out:
#                                              EMPRESA     CIFRA  CIUDAD
# 0  ACCIONISTA MAYORITARIO DE INDITEX\nCONFECCIÓNG...  67.000 M    None
# 1           ACCIONISTA DE INDITEX\nCONFECCIÓNGALICIA   6.300 M    None
# 2    PRESIDENTE DE FERROVIAL\nINFRAESTRUCTURASMADRID   3.800 M    None
# 3  PRESIDENTE DE MERCADONA\nDISTRIBUCIÓNC. VALENC...   3.700 M    None
# 4  PRESIDENTE DEL BANESCO GRUPO FINANCIERO INTERN...   2.700 M    None
# 5  PRESIDENTE DE HONOR DE TORREAL\nINVERSIONESMADRID   2.500 M    None
# 6                       PROPIETARIA DE OMEGA CAPITAL  2.300 M€  MADRID

# %%
for e in df_3.EMPRESA:
    e.strip('\n')[0]

# %%
df_3 = df_3.replace('\n',' ', regex=True)

# %%
df_3.head(6)
# Out:
#                                              EMPRESA     CIFRA CIUDAD
# 0  ACCIONISTA MAYORITARIO DE INDITEX CONFECCIÓNGA...  67.000 M   None
# 1            ACCIONISTA DE INDITEX CONFECCIÓNGALICIA   6.300 M   None
# 2     PRESIDENTE DE FERROVIAL INFRAESTRUCTURASMADRID   3.800 M   None
# 3  PRESIDENTE DE MERCADONA DISTRIBUCIÓNC. VALENCIANA   3.700 M   None
# 4  PRESIDENTE DEL BANESCO GRUPO FINANCIERO INTERN...   2.700 M   None
# 5   PRESIDENTE DE HONOR DE TORREAL INVERSIONESMADRID   2.500 M   None

# %%
df_3['EMPRESA'].iloc[0] = 'ACCIONISTA MAYORITARIO DE INDITEX'

# %%
df_3['CIUDAD'].iloc[0] = 'GALICIA'

# %%
df_3['EMPRESA'].iloc[1] = 'ACCIONISTA DE INDITEX'

# %%
df_3['CIUDAD'].iloc[1] = 'GALICIA'

# %%
df_3['EMPRESA'].iloc[2] = 'PRESIDENTE DE FERROVIAL'

# %%
df_3['CIUDAD'].iloc[2] = 'MADRID'

# %%
df_3['EMPRESA'].iloc[3] = 'PRESIDENTE DE MERCADONA'

# %%
df_3['CIUDAD'].iloc[3] = 'C. VALENCIANA'

# %%
df_3['EMPRESA'].iloc[4] = 'PRESIDENTE DEL BANESCO GRUPO FINANCIERO INTERNACIONAL Y DE ABANCA CORPORACIÓN BANCARIA'

# %%
df_3['CIUDAD'].iloc[4] = 'GALICIA'

# %%
df_3['EMPRESA'].iloc[5] = 'PRESIDENTE DE HONOR DE TORREAL'

# %%
df_3['CIUDAD'].iloc[5] = 'MADRID'

# %%
df_3.head()
# Out:
#                                              EMPRESA     CIFRA         CIUDAD
# 0                  ACCIONISTA MAYORITARIO DE INDITEX  67.000 M        GALICIA
# 1                              ACCIONISTA DE INDITEX   6.300 M        GALICIA
# 2                            PRESIDENTE DE FERROVIAL   3.800 M         MADRID
# 3                            PRESIDENTE DE MERCADONA   3.700 M  C. VALENCIANA
# 4  PRESIDENTE DEL BANESCO GRUPO FINANCIERO INTERN...   2.700 M        GALICIA

# %%
df_3.rename(columns = {'EMPRESA' : 'CARGO'}, inplace = True)

# %%
df_3.rename(columns = {'CIUDAD' : 'COMUNIDAD_AUTONOMA'}, inplace = True)

# %%
df_3
# Out:
#                                                 CARGO     CIFRA  \
# 0                   ACCIONISTA MAYORITARIO DE INDITEX  67.000 M
# 1                               ACCIONISTA DE INDITEX   6.300 M
# 2                             PRESIDENTE DE FERROVIAL   3.800 M
# 3                             PRESIDENTE DE MERCADONA   3.700 M
# 4   PRESIDENTE DEL BANESCO GRUPO FINANCIERO INTERN...   2.700 M
# 5                      PRESIDENTE DE HONOR DE TORREAL   2.500 M
# 6                        PROPIETARIA DE OMEGA CAPITAL  2.300 M€
# 7                             ACCIONISTA DE MERCADONA  2.300 M€
# 8          PRESIDENTA DE LA FUNDACIÓN RAFAEL DEL PINO  2.200 M€
# 9                              ACCIONISTA DE GLENCORE  2.200 M€
# 10       PRESIDENTA DE COCA-COLA EUROPACIFIC PARTNERS  1.900 M€
# 11                                  PRESIDENTE DE ACS  1.700 M€
# 12                            ACCIONISTA DE FERROVIAL  1.600 M€
# 13                               PROPIETARIO DE MANGO  1.600 M€
# ...

# %%
def meter_euro(CIFRA):
    if '€' not in CIFRA:
        return CIFRA + '€'
    else:
        return CIFRA

# %%
df_3['CIFRA'] = df_3['CIFRA'].apply(meter_euro)

# %%
df_3
# Out:
#                                                 CARGO      CIFRA  \
# 0                   ACCIONISTA MAYORITARIO DE INDITEX  67.000 M€
# 1                               ACCIONISTA DE INDITEX   6.300 M€
# 2                             PRESIDENTE DE FERROVIAL   3.800 M€
# 3                             PRESIDENTE DE MERCADONA   3.700 M€
# 4   PRESIDENTE DEL BANESCO GRUPO FINANCIERO INTERN...   2.700 M€
# 5                      PRESIDENTE DE HONOR DE TORREAL   2.500 M€
# 6                        PROPIETARIA DE OMEGA CAPITAL   2.300 M€
# 7                             ACCIONISTA DE MERCADONA   2.300 M€
# 8          PRESIDENTA DE LA FUNDACIÓN RAFAEL DEL PINO   2.200 M€
# 9                              ACCIONISTA DE GLENCORE   2.200 M€
# 10       PRESIDENTA DE COCA-COLA EUROPACIFIC PARTNERS   1.900 M€
# 11                                  PRESIDENTE DE ACS   1.700 M€
# 12                            ACCIONISTA DE FERROVIAL   1.600 M€
# ...

# %%
df_3.head()
# Out:
#                                                CARGO      CIFRA  \
# 0                  ACCIONISTA MAYORITARIO DE INDITEX  67.000 M€
# 1                              ACCIONISTA DE INDITEX   6.300 M€
# 2                            PRESIDENTE DE FERROVIAL   3.800 M€
# 3                            PRESIDENTE DE MERCADONA   3.700 M€
# 4  PRESIDENTE DEL BANESCO GRUPO FINANCIERO INTERN...   2.700 M€
#
#   COMUNIDAD_AUTÓNOMA
# 0            GALICIA
# 1            GALICIA
# 2             MADRID
# 3      C. VALENCIANA
# 4            GALICIA

# %%
forbes_sp = pd.concat([df_forbes_sp, df_3], axis=1)

# %%
forbes_sp.head()
# Out:
#                            NOMBRE  \
# 0                  Amancio Ortega
# 1              Sandra Ortega Mera
# 2  Rafael del Pino y Calvo-Sotelo
# 3               Juan Roig Alfonso
# 4             Juan Carlos Escotet
#
#                                                CARGO      CIFRA  \
# 0                  ACCIONISTA MAYORITARIO DE INDITEX  67.000 M€
# 1                              ACCIONISTA DE INDITEX   6.300 M€
# 2                            PRESIDENTE DE FERROVIAL   3.800 M€
# 3                            PRESIDENTE DE MERCADONA   3.700 M€
# 4  PRESIDENTE DEL BANESCO GRUPO FINANCIERO INTERN...   2.700 M€
#
#   COMUNIDAD_AUTÓNOMA
# 0            GALICIA
# 1            GALICIA
# 2             MADRID
# 3      C. VALENCIANA
# 4            GALICIA

# %%
len(forbes_sp)
# Out:
# 100

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/rociomoreno/Desktop/IRONHACK/SCRAPPING/Proyecto_3'

# %%
os.chdir('./DATA')

# %%
forbes_world = pd.read_csv('./2022_forbes_billionaires.csv')

# %%
forbes_world.head()
# Out:
#    rank                       name networth  age        country  \
# 0     1                 Elon Musk    $219 B   50  United States
# 1     2                Jeff Bezos    $171 B   58  United States
# 2     3  Bernard Arnault & family    $158 B   73         France
# 3     4                Bill Gates    $129 B   66  United States
# 4     5            Warren Buffett    $118 B   91  United States
#
#                source                industry
# 0       Tesla, SpaceX             Automotive
# 1              Amazon             Technology
# 2                LVMH       Fashion & Retail
# 3           Microsoft             Technology
# 4  Berkshire Hathaway  Finance & Investments

# %%
forbes_world.drop(columns = ['Unnamed: 0'], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [78], in <cell line: 1>()
# ----> 1 forbes_world.drop(columns = ['Unnamed: 0'], inplace = True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %%
forbes_world.columns=[c.upper().replace(' ', '') for c in forbes_world.columns]

# %%
forbes_world.head()
# Out:
#    RANK                       NAME NETWORTH  AGE        COUNTRY  \
# 0     1                 Elon Musk    $219 B   50  United States
# 1     2                Jeff Bezos    $171 B   58  United States
# 2     3  Bernard Arnault & family    $158 B   73         France
# 3     4                Bill Gates    $129 B   66  United States
# 4     5            Warren Buffett    $118 B   91  United States
#
#                SOURCE                INDUSTRY
# 0       Tesla, SpaceX             Automotive
# 1              Amazon             Technology
# 2                LVMH       Fashion & Retail
# 3           Microsoft             Technology
# 4  Berkshire Hathaway  Finance & Investments

# %%
empresas1= []
for e in forbes_sp.CARGO:
    if ' DE ' in e :
        empresas1.append(e.split(' DE ')[-1])
    elif ' DEL ' in e:
        empresas1.append(e.split(' DEL')[-1])
    elif 'DE ' in e:
        empresas1.append(e.split('DE ')[-1])
    else:
        empresas1.append(e)

# %%
len(empresas1)
# Out:
# 100

# %%
forbes_sp.insert(4, 'EMPRESA', empresas1)

# %%
ids = []

# %%
forbes_sp.insert(0, 'ID', [e for e in range(len(forbes_sp))] )

# %%
forbes_sp.head()
# Out:
#    ID                          NOMBRE  \
# 0   0                  Amancio Ortega
# 1   1              Sandra Ortega Mera
# 2   2  Rafael del Pino y Calvo-Sotelo
# 3   3               Juan Roig Alfonso
# 4   4             Juan Carlos Escotet
#
#                                                CARGO      CIFRA  \
# 0                  ACCIONISTA MAYORITARIO DE INDITEX  67.000 M€
# 1                              ACCIONISTA DE INDITEX   6.300 M€
# 2                            PRESIDENTE DE FERROVIAL   3.800 M€
# 3                            PRESIDENTE DE MERCADONA   3.700 M€
# 4  PRESIDENTE DEL BANESCO GRUPO FINANCIERO INTERN...   2.700 M€
#
#   COMUNIDAD_AUTÓNOMA                      EMPRESA
# 0            GALICIA                      INDITEX
# 1            GALICIA                      INDITEX
# 2             MADRID                    FERROVIAL
# 3      C. VALENCIANA                    MERCADONA
# 4            GALICIA  ABANCA CORPORACIÓN BANCARIA

# %%
forbes_world.head()
# Out:
#    RANK                       NAME NETWORTH  AGE        COUNTRY  \
# 0     1                 Elon Musk    $219 B   50  United States
# 1     2                Jeff Bezos    $171 B   58  United States
# 2     3  Bernard Arnault & family    $158 B   73         France
# 3     4                Bill Gates    $129 B   66  United States
# 4     5            Warren Buffett    $118 B   91  United States
#
#                SOURCE                INDUSTRY
# 0       Tesla, SpaceX             Automotive
# 1              Amazon             Technology
# 2                LVMH       Fashion & Retail
# 3           Microsoft             Technology
# 4  Berkshire Hathaway  Finance & Investments

# %%
forbes_world.rename(columns = {'RANK' : 'ID'}, inplace = True)

# %%
#una vez limpias, las subimos a MYSQL

# %%
str_conn='mysql+pymysql://root:01051997Rm@localhost:3306/listas_forbes'

cursor=create_engine(str_conn)

# %%
forbes_world.to_sql(name='forbes_world', con=cursor, if_exists='replace', index=False)
# Out:
# 2600

# %%
forbes_sp.to_sql(name='forbes_sp', con=cursor, if_exists='replace', index=False)
# Out:
# 100
